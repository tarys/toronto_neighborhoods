# %% [markdown]
# This notebook contains individual assignment _Segmenting and Clustering Neighborhoods in Toronto_ for Week 3 of [Applied Data Science Capstone](https://www.coursera.org/learn/applied-data-science-capstone) course.

# %% [markdown]
# ## Table of Contents :
# * [Install libraries](#install-libraries)
# * [Import libraries](#import-libraries)
# * [Display options for Pandas](#display-options-for-pandas)
# * [Scrape Toronto Neighborhoods data](#scrape-toronto-neighborhoods-data)
# * [Obtaining latitude and the longitude coordinates for neighborhoods](#obtaining-latitude-and-the-longitude-coordinates-for-neighborhoods)
# * [Displaying neighborhoods on the map](#displaying-neighborhoods-on-the-map)
# * [Explore and cluster the neighborhoods](#explore-and-cluster-the-neighborhoods)

# %% [markdown]
# # Install libraries <a class="anchor" id="install-libraries"></a>

# %%
# !pip3 install beautifulsoup4 lxml requests pandas numpy geopy sklearn folium matplotlib

# %% [markdown]
# # Import libraries <a class="anchor" id="import-libraries"></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim
import numpy as np
from sklearn.cluster import KMeans
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# # Display options for Pandas <a class="anchor" id="display-options-for-pandas"></a>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Scrape Toronto Neighborhoods data <a class="anchor" id="scrape-toronto-neighborhoods-data"></a>

# %% [markdown]
# Get content of https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M as source to be scraped:

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source, 'lxml')

# %% [markdown]
# Selecting only HTML-snippet with rows of table:

# %%
table_rows = soup.select('table.wikitable > tbody > tr')

# %% [markdown]
# Removing 1st row that is a header:

# %%
table_rows_without_header = table_rows[1:]

# %% [markdown]
# Collecting table data into Python list data structure:

# %%
scraped_list = []
for tr in table_rows_without_header:
    td = tr.find_all('td')
    scraped_list.append((td[0].text, td[1].text, td[2].text.rstrip('\n')))

# %% [markdown]
# Creating empty dataframe:

# %%
scraped_neighborhoods_raw = pd.DataFrame(scraped_list, columns=['Postal Code', 'Borough', 'Neighborhood'])

# %% [markdown]
# Filtering out rows, where _Borough_ column has `Not assigned` value:

# %%
scraped_neighborhoods_filtered_na_boroughs = scraped_neighborhoods_raw[scraped_neighborhoods_raw['Borough'] != 'Not assigned']

# %% [markdown]
# Combine neighborhoods with same _PostalCode_ into single row:

# %%
scraped_neighborhoods_clean = scraped_neighborhoods_filtered_na_boroughs.groupby(['Postal Code', 'Borough'], as_index=False, sort=False).agg({'Neighborhood': lambda x: "%s" % ', '.join(x)})

# %% [markdown]
# For all rows, where _Borough_ is known, but _Neighborhood_ is `Not assigned` the neighborhood will be the same as the borough:

# %%
borough_for_not_assigned_neighborhoods = scraped_neighborhoods_clean[scraped_neighborhoods_clean['Neighborhood'] == 'Not assigned']['Borough']
scraped_neighborhoods_clean.loc[scraped_neighborhoods_clean['Neighborhood'] == 'Not assigned', 'Neighborhood'] = borough_for_not_assigned_neighborhoods

# %%
scraped_neighborhoods_clean.shape
# Out:
# (103, 3)

# %% [markdown]
# # Obtaining latitude and the longitude coordinates for neighborhoods <a class="anchor" id="obtaining-latitude-and-the-longitude-coordinates-for-neighborhoods"></a>

# %% [markdown]
# As `geocoder` lib is very unstable, let's load data from http://cocl.us/Geospatial_data CSV-file:

# %%
geospatial_data = pd.read_csv('http://cocl.us/Geospatial_data')

# %% [markdown]
# Now, let's merge 2 existing dataframes into single one:

# %%
neighborhoods = pd.merge(scraped_neighborhoods_clean, geospatial_data, on='Postal Code')

# %% [markdown]
# # Displaying neighborhoods on the map <a class="anchor" id="displaying-neighborhoods-on-the-map"></a>

# %% [markdown]
# Obtaining Toronto latitude and longitude values:

# %%
address = 'Toronto, ON, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
toronto_location = geolocator.geocode(address)
toronto_latitude = toronto_location.latitude
toronto_longitude = toronto_location.longitude

# %% [markdown]
# Create a map of Toronto using latitude and longitude values:

# %%
map_newyork = folium.Map(location=[toronto_latitude, toronto_longitude], zoom_start=10)

# %% [markdown]
# Add neighborhoods markers to map:

# %%
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Explore and cluster the neighborhoods <a class="anchor" id="explore-and-cluster-the-neighborhoods"></a>

# %% [markdown]
# Define Foursquare Credentials and Version:

# %%
CLIENT_ID = 'put your real Client ID here'
CLIENT_SECRET = 'put your real Client Secret here'
VERSION = '20180605'

# %% [markdown]
# "Borrowed" the get_category_type function from the Foursquare lab:

# %%
def get_nearby_venues(names, latitudes, longitudes, radius=500, limit=100):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        if results:
            print("Found {number} venues for '{name}' neighborhood.".format(number=len(results), name=name))
        else:
            print("WARNING: No venues found for '{name}' neighborhood.".format(name=name))
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Run the above function on each neighborhood and create a new dataframe with venues information:

# %%
toronto_venues = get_nearby_venues(names=neighborhoods['Neighborhood'],
                                 latitudes=neighborhoods['Latitude'],
                                 longitudes=neighborhoods['Longitude']
                                )
# Out:
# Found 3 venues for 'Parkwoods' neighborhood.
# Found 4 venues for 'Victoria Village' neighborhood.
# Found 48 venues for 'Harbourfront, Regent Park' neighborhood.
# Found 16 venues for 'Lawrence Heights, Lawrence Manor' neighborhood.
# Found 39 venues for 'Queen's Park' neighborhood.
# WARNING: No venues found for 'Islington Avenue' neighborhood.
# Found 2 venues for 'Rouge, Malvern' neighborhood.
# Found 5 venues for 'Don Mills North' neighborhood.
# Found 13 venues for 'Woodbine Gardens, Parkview Hill' neighborhood.
# Found 100 venues for 'Ryerson, Garden District' neighborhood.
# Found 4 venues for 'Glencairn' neighborhood.
# Found 1 venues for 'Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park' neighborhood.
# Found 2 venues for 'Highland Creek, Rouge Hill, Port Union' neighborhood.
# Found 23 venues for 'Flemingdon Park, Don Mills South' neighborhood.
# Found 8 venues for 'Woodbine Heights' neighborhood.
# Found 100 venues for 'St. James Town' neighborhood.
# Found 4 venues for 'Humewood-Cedarvale' neighborhood.
# Found 6 venues for 'Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe' neighborhood.
# Found 9 venues for 'Guildwood, Morningside, West Hill' neighborhood.
# Found 5 venues for 'The Beaches' neighborhood.
# Found 55 venues for 'Berczy Park' neighborhood.
# Found 6 venues for 'Caledonia-Fairbanks' neighborhood.
# Found 4 venues for 'Woburn' neighborhood.
# Found 35 venues for 'Leaside' neighborhood.
# Found 88 venues for 'Central Bay Street' neighborhood.
# Found 15 venues for 'Christie' neighborhood.
# Found 8 venues for 'Cedarbrae' neighborhood.
# Found 4 venues for 'Hillcrest Village' neighborhood.
# Found 18 venues for 'Bathurst Manor, Downsview North, Wilson Heights' neighborhood.
# Found 18 venues for 'Thorncliffe Park' neighborhood.
# Found 100 venues for 'Adelaide, King, Richmond' neighborhood.
# Found 20 venues for 'Dovercourt Village, Dufferin' neighborhood.
# Found 1 venues for 'Scarborough Village' neighborhood.
# Found 66 venues for 'Fairview, Henry Farm, Oriole' neighborhood.
# Found 7 venues for 'Northwood Park, York University' neighborhood.
# Found 3 venues for 'East Toronto' neighborhood.
# Found 100 venues for 'Harbourfront East, Toronto Islands, Union Station' neighborhood.
# Found 62 venues for 'Little Portugal, Trinity' neighborhood.
# Found 4 venues for 'East Birchmount Park, Ionview, Kennedy Park' neighborhood.
# Found 4 venues for 'Bayview Village' neighborhood.
# Found 3 venues for 'CFB Toronto, Downsview East' neighborhood.
# Found 42 venues for 'The Danforth West, Riverdale' neighborhood.
# Found 100 venues for 'Design Exchange, Toronto Dominion Centre' neighborhood.
# Found 22 venues for 'Brockton, Exhibition Place, Parkdale Village' neighborhood.
# Found 10 venues for 'Clairlea, Golden Mile, Oakridge' neighborhood.
# Found 1 venues for 'Silver Hills, York Mills' neighborhood.
# Found 4 venues for 'Downsview West' neighborhood.
# Found 18 venues for 'The Beaches West, India Bazaar' neighborhood.
# Found 100 venues for 'Commerce Court, Victoria Hotel' neighborhood.
# Found 5 venues for 'Downsview, North Park, Upwood Park' neighborhood.
# Found 3 venues for 'Humber Summit' neighborhood.
# Found 3 venues for 'Cliffcrest, Cliffside, Scarborough Village West' neighborhood.
# WARNING: No venues found for 'Newtonbrook, Willowdale' neighborhood.
# Found 4 venues for 'Downsview Central' neighborhood.
# Found 38 venues for 'Studio District' neighborhood.
# Found 25 venues for 'Bedford Park, Lawrence Manor East' neighborhood.
# Found 4 venues for 'Del Ray, Keelesdale, Mount Dennis, Silverthorn' neighborhood.
# Found 1 venues for 'Emery, Humberlea' neighborhood.
# Found 4 venues for 'Birch Cliff, Cliffside West' neighborhood.
# Found 37 venues for 'Willowdale South' neighborhood.
# Found 5 venues for 'Downsview Northwest' neighborhood.
# Found 3 venues for 'Lawrence Park' neighborhood.
# Found 2 venues for 'Roselawn' neighborhood.
# Found 4 venues for 'The Junction North, Runnymede' neighborhood.
# Found 2 venues for 'Weston' neighborhood.
# Found 6 venues for 'Dorset Park, Scarborough Town Centre, Wexford Heights' neighborhood.
# Found 5 venues for 'York Mills West' neighborhood.
# Found 9 venues for 'Davisville North' neighborhood.
# Found 4 venues for 'Forest Hill North, Forest Hill West' neighborhood.
# Found 23 venues for 'High Park, The Junction South' neighborhood.
# Found 6 venues for 'Westmount' neighborhood.
# Found 7 venues for 'Maryvale, Wexford' neighborhood.
# Found 5 venues for 'Willowdale West' neighborhood.
# Found 16 venues for 'North Toronto West' neighborhood.
# Found 23 venues for 'The Annex, North Midtown, Yorkville' neighborhood.
# Found 15 venues for 'Parkdale, Roncesvalles' neighborhood.
# Found 10 venues for 'Canada Post Gateway Processing Centre' neighborhood.
# Found 4 venues for 'Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips' neighborhood.
# Found 4 venues for 'Agincourt' neighborhood.
# Found 38 venues for 'Davisville' neighborhood.
# Found 34 venues for 'Harbord, University of Toronto' neighborhood.
# Found 38 venues for 'Runnymede, Swansea' neighborhood.
# Found 10 venues for 'Clarks Corners, Sullivan, Tam O'Shanter' neighborhood.
# Found 2 venues for 'Moore Park, Summerhill East' neighborhood.
# Found 100 venues for 'Chinatown, Grange Park, Kensington Market' neighborhood.
# Found 3 venues for 'Agincourt North, L'Amoreaux East, Milliken, Steeles East' neighborhood.
# Found 14 venues for 'Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West' neighborhood.
# Found 15 venues for 'CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara' neighborhood.
# Found 15 venues for 'Humber Bay Shores, Mimico South, New Toronto' neighborhood.
# Found 11 venues for 'Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown' neighborhood.
# Found 12 venues for 'L'Amoreaux West' neighborhood.
# Found 4 venues for 'Rosedale' neighborhood.
# Found 94 venues for 'Stn A PO Boxes 25 The Esplanade' neighborhood.
# Found 10 venues for 'Alderwood, Long Branch' neighborhood.
# Found 3 venues for 'Northwest' neighborhood.
# WARNING: No venues found for 'Upper Rouge' neighborhood.
# Found 46 venues for 'Cabbagetown, St. James Town' neighborhood.
# Found 100 venues for 'First Canadian Place, Underground city' neighborhood.
# Found 3 venues for 'The Kingsway, Montgomery Road, Old Mill North' neighborhood.
# Found 87 venues for 'Church and Wellesley' neighborhood.
# Found 19 venues for 'Business Reply Mail Processing Centre 969 Eastern' neighborhood.
# Found 1 venues for 'Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea' neighborhood.
# Found 12 venues for 'Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor' neighborhood.

# %% [markdown]
# One hot encoding:

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# %% [markdown]
# Move neighborhood column to the first column:

# %%
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 
cols = list(toronto_onehot)
cols.insert(0, cols.pop(cols.index('Neighborhood')))
toronto_onehot = toronto_onehot.loc[:, cols]

# %% [markdown]
# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category:

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# Function to sort the venues in descending order:

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# New dataframe with top 10 venues for each neighborhood:

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters:

# %%
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# %% [markdown]
# Add clustering labels to dataframe:

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %% [markdown]
# Dropping neighborhoods:
# - Islington Avenue
# - Newtonbrook, Willowdale
# - Upper Rouge
#
# because no venues found in them by `get_nearby_venues` function:

# %%
neighborhoods_with_venues = neighborhoods[~neighborhoods['Neighborhood'].isin(['Islington Avenue', 'Newtonbrook, Willowdale', 'Upper Rouge'])].reset_index(drop=True)

# %% [markdown]
# Merge `neighborhoods_venues_sorted` with `neighborhoods_with_venues` to add latitude/longitude for each neighborhood:

# %%
toronto_merged = neighborhoods_with_venues.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %% [markdown]
# Visualize the resulting clusters:

# %%
map_clusters = folium.Map(location=[toronto_latitude, toronto_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
